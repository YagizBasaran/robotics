# %% [markdown]
# # Ring Throw Parameter Sweeping
#
# This notebook demonstrates how to:
# 1. Load the robotics environment with RAI.
# 2. Parameterize certain variables in the ring-throw code.
# 3. Loop over a range of values for those parameters.
# 4. Run the simulation for each combination.
# 5. Log the outcomes to a CSV.

# %%
import robotic as ry
import numpy as np
import os

# Set the DISPLAY environment variable
os.environ['DISPLAY'] = ':0'

# Global environment setup
C = ry.Config()
C.addFile("/home/yagz/rai_venv/robotics/penvironment.g")  # Adjust path if needed
C.view(False)
bot = ry.BotOp(C, useRealRobot=False)
bot.home(C)

# -----------------------------
#  Utility & Helper Functions
# -----------------------------

def align_gripper_to_ring():
    approach_waypoint = C.addFrame('approach_waypoint', 'ring1')  # Using ring1 for alignment
    align_waypoint = C.addFrame('align_waypoint', 'ring1')
    approach_waypoint.setShape(ry.ST.marker, size=[.1])
    approach_waypoint.setRelativePose('t(0 0 0.1) d(90 0 0 0)')  # Position above ring1

    align_waypoint.setShape(ry.ST.marker, size=[.1])
    align_waypoint.setRelativePose(' d(90 0 0 0)')  # Align directly to ring1

    komo = ry.KOMO()
    komo.setConfig(C, True)
    komo.setTiming(2., 1, 5., 0)
    komo.addControlObjective([], 0, 1e-0)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq, [1e1])
    komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
    komo.addObjective([1.], ry.FS.positionDiff, ['l_gripper', 'approach_waypoint'], ry.OT.eq, [1e2])
    komo.addObjective([2.], ry.FS.positionDiff, ['l_gripper', 'align_waypoint'], ry.OT.eq, [1e2])

    solver = ry.NLP_Solver()
    solver.setProblem(komo.nlp())
    solver.setOptions(stopTolerance=1e-2, verbose=4)
    solver.solve()

    return komo.getPath()

def grasp_ring():
    bot.gripperCloseGrasp(ry._left, 'ring1', force=10.0, width=0, speed=1)
    while not bot.gripperDone(ry._left):
        bot.sync(C, 0.1)
    print("Ring successfully grasped by the gripper.")

def strech():
    strech_frame1 = C.addFrame('strech_frame1', 'table')
    strech_frame1.setShape(ry.ST.marker, size=[.1])
    strech_frame1.setRelativePosition([0, 2.5, 0.5])

    komo = ry.KOMO()
    komo.setConfig(C, True)
    komo.setTiming(2., 1, 5., 1)
    komo.addControlObjective([], 0, 1e-0)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq, [1e1])
    komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
    komo.addObjective([1.], ry.FS.positionDiff, ['l_gripper', 'strech_frame1'], ry.OT.eq, [1e1], order=0)

    solver = ry.NLP_Solver()
    solver.setProblem(komo.nlp())
    solver.setOptions(stopTolerance=1e-2, verbose=4)
    solver.solve()

    return komo.getPath()

def throw():
    rel_point = [0, 1.6, 1]
    komo = ry.KOMO()
    komo.setConfig(C, True)
    komo.setTiming(2., 1, 5., 1)
    komo.addControlObjective([], 0, 1e-0)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq, [1e1])
    komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)

    # Position objective
    komo.addObjective([1.], ry.FS.position, ['l_gripper'], ry.OT.eq, [1e1], target=rel_point)
    # Velocity objective
    komo.addObjective([1.], ry.FS.position, ['l_gripper'], ry.OT.eq, [1e1],
                      target=[0, -3.4, 8.355], order=1)

    solver = ry.NLP_Solver()
    solver.setProblem(komo.nlp())
    solver.setOptions(stopTolerance=1e-2, verbose=4)
    solver.solve()

    return komo.getPath()

# Placeholder for success detection logic
def is_ring_on_pole():
    """
    Implement your real check if ring ended on the pole.
    Currently returns False always.
    """
    return False

# -----------------------------
#  Core Parametrized Function
# -----------------------------
def run_ring_throw(q2_val, time1, time2, release_threshold):
    """
    Executes the ring pick-and-throw sequence, using:
      - q2_val in [-0.51..-0.11] for q[2]
      - (time1, time2) in ([0..0.2], [1..1.5]) for the throw move
      - release_threshold in [0.4..0.7]

    Returns True if 'ring on pole' success, else False.
    """

    # 1) Align with the ring
    grasp_path = align_gripper_to_ring()
    # keep the align times as [1., 1.5]
    bot.move(grasp_path, [1.0, 1.5])
    # If you want to see the motion without waiting too long, reduce the second param or skip wait:
    bot.wait(C, forKeyPressed=False, forTimeToEnd=True)

    # 2) Grasp ring
    grasp_ring()
    bot.wait(C, forKeyPressed=False, forTimeToEnd=True)

    # 3) Adjust q[2] & q[3]
    q = bot.get_qHome()
    q[2] = q2_val          # param in [-0.51..-0.11]
    q[3] = q[3] + 4        # same as original code
    bot.moveTo(q)
    bot.wait(C, forKeyPressed=False, forTimeToEnd=True)

    # 4) Compute throw path
    throw_path = throw()
    bot.move(throw_path, [time1, time2])  # param in [time1, time2]

    # 5) Release logic
    while bot.getTimeToEnd() > 0:
        bot.sync(C, 0.05)
        gripper_position = C.frame("l_gripper").getPosition()
        gripper_height = gripper_position[2]

        # if gripper_height > release_threshold => open gripper
        if gripper_height > release_threshold:
            bot.gripperMove(ry._left, width=10, speed=10)

    # If you want the block to end quickly, you can skip the final wait or shorten it:
    bot.wait(C, forKeyPressed=False, forTimeToEnd=True)

    # Evaluate success
    success = is_ring_on_pole()
    return success

# Example single-run test
def test_run():
    """
    Single-run test without blocking input().
    """
    print("Running a quick test throw...")
    result = run_ring_throw(
        q2_val=-0.31,
        time1=0.1,
        time2=1.2,
        release_threshold=0.52
    )
    print("Test run success?", result)

# We'll just call the test_run() function at the end of the cell.
test_run()
print("Block completed. If the cell still runs indefinitely, remove or shorten wait calls.")
# Out:
# -- WARNING:graph.cpp:edit:494(-1) no nodes edited! (from 'panda_finger_joint1: { joint_active! }')
# -- WARNING:kin_physx.cpp:prepareLinkShapes:625(-1) computing compound inertia for object frame 'ring' -- this should have been done earlier?
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):5966.48 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     3200.5  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    1793.12  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    898.333  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    346.398  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    68.2359  ACCEPT
# --newton-- it:   6  |Delta|:   0.152383  alpha:          1  evals:   7  f(y):    13.2498  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):     11.716  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    12.4183  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  10  f(y):    11.5506  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:       0.75  evals:  11  f(y):    11.8151  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  12  f(y):    11.4493  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:     0.5625  evals:  13  f(y):    11.4891  reject (lineSearch:0)
#                     (line search)        alpha:    0.28125  evals:  14  f(y):    11.4319  ACCEPT
# --newton-- it:  11  |Delta|:   0.186723  alpha:   0.421875  evals:  15  f(y):    11.4982  reject (lineSearch:0)
#                     (line search)        alpha:   0.210938  evals:  16  f(y):    11.3593  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:   0.316406  evals:  17  f(y):    11.4723  reject (lineSearch:0)
#                     (line search)        alpha:   0.158203  evals:  18  f(y):    11.4001  reject (lineSearch:1)
#                     (line search)        alpha:  0.0791016  evals:  19  f(y):     11.374  reject (lineSearch:2)
#                     (line search)        alpha:  0.0395508  evals:  20  f(y):     11.363  reject (lineSearch:3)
#                     (line search)        alpha:  0.0197754  evals:  21  f(y):     11.358  ACCEPT
# --newton-- it:  13  |Delta|:   0.163102  alpha:  0.0296631  evals:  22  f(y):    11.3598  reject (lineSearch:0)
#                     (line search)        alpha:  0.0148315  evals:  23  f(y):    11.3532  ACCEPT
# --newton-- it:  14  |Delta|:        0.2  alpha:  0.0222473  evals:  24  f(y):    11.3665  reject (lineSearch:0)
#                     (line search)        alpha:  0.0111237  evals:  25  f(y):    11.3589  reject (lineSearch:1)
#                     (line search)        alpha: 0.00556183  evals:  26  f(y):    11.3552  reject (lineSearch:2)
#                     (line search)        alpha: 0.00278091  evals:  27  f(y):    11.3533  reject (lineSearch:3)
#                     (line search)        alpha: 0.00139046  evals:  28  f(y):    11.3527  ACCEPT
# --newton-- it:  15  |Delta|:   0.161304  alpha: 0.00208569  evals:  29  f(y):    11.3534  reject (lineSearch:0)
#                     (line search)        alpha: 0.00104284  evals:  30  f(y):    11.3529  reject (lineSearch:1)
#                     (line search)        alpha:0.000521421  evals:  31  f(y):    11.3527  ACCEPT
# --newton-- it:  16  |Delta|:        0.2  alpha:0.000782132  evals:  32  f(y):    11.3527  ACCEPT
# --newton-- it:  17  |Delta|:   0.161352  alpha:  0.0011732  evals:  33  f(y):    11.3527  reject (lineSearch:0)
#                     (line search)        alpha:0.000586599  evals:  34  f(y):    11.3525  ACCEPT
# --newton-- it:  18  |Delta|:   0.161289  alpha:0.000879899  evals:  35  f(y):    11.3528  reject (lineSearch:0)
#                     (line search)        alpha:0.000439949  evals:  36  f(y):    11.3526  reject (lineSearch:1)
#                     (line search)        alpha:0.000219975  evals:  37  f(y):    11.3525  reject (lineSearch:2)
#                     (line search)        alpha:0.000109987  evals:  38  f(y):    11.3524  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   0  evals:  38  A(x):    11.3524  f:    3.29693  g:          0  h:    4.47112  |x-x'|:    1.13538 	stop:TinyXSteps (bad:1)
# ==nlp== it:   1  evals:  38  A(x):    59.6855  mu:5
# --newton-- it:  19  |Delta|:        0.2  alpha:       0.01  evals:  39  f(y):    59.6989  reject (lineSearch:0)
#                     (line search)        alpha:      0.005  evals:  40  f(y):    59.6918  reject (lineSearch:1)
#                     (line search)        alpha:     0.0025  evals:  41  f(y):    59.6883  reject (lineSearch:2)
#                     (line search)        alpha:    0.00125  evals:  42  f(y):    59.6865  reject (lineSearch:3)
#                     (line search)        alpha:   0.000625  evals:  43  f(y):    59.6856  reject (lineSearch:4)
#                     (line search)        alpha:  0.0003125  evals:  44  f(y):    59.6854  ACCEPT
# --newton-- it:  20  |Delta|:   0.161319  alpha: 0.00046875  evals:  45  f(y):    59.6858  reject (lineSearch:0)
#                     (line search)        alpha:0.000234375  evals:  46  f(y):    59.6851  ACCEPT
# --newton-- it:  21  |Delta|:   0.161294  alpha:0.000351562  evals:  47  f(y):    59.6863  reject (lineSearch:0)
#                     (line search)        alpha:0.000175781  evals:  48  f(y):    59.6856  reject (lineSearch:1)
#                     (line search)        alpha:8.78906e-05  evals:  49  f(y):    59.6853  reject (lineSearch:2)
#                     (line search)        alpha:4.39453e-05  evals:  50  f(y):    59.6851  ACCEPT
# --newton-- it:  22  |Delta|:   0.161289  alpha: 6.5918e-05  evals:  51  f(y):    59.6853  reject (lineSearch:0)
#                     (line search)        alpha: 3.2959e-05  evals:  52  f(y):    59.6852  reject (lineSearch:1)
#                     (line search)        alpha:1.64795e-05  evals:  53  f(y):    59.6851  reject (lineSearch:2)
#                     (line search)        alpha:8.23975e-06  evals:  54  f(y):    59.6851  reject (lineSearch:3)
#                     (line search)        alpha:4.11987e-06  evals:  55  f(y):    59.6851  ACCEPT
# --newton-- it:  23  |Delta|:   0.161289  alpha:6.17981e-06  evals:  56  f(y):    59.6851  reject (lineSearch:0)
#                     (line search)        alpha: 3.0899e-06  evals:  57  f(y):    59.6851  reject (lineSearch:1)
#                     (line search)        alpha:1.54495e-06  evals:  58  f(y):    59.6851  reject (lineSearch:2)
#                     (line search)        alpha:7.72476e-07  evals:  59  f(y):    59.6851  reject (lineSearch:3)
#                     (line search)        alpha:3.86238e-07  evals:  60  f(y):    59.6851  reject (lineSearch:4)
#                     (line search)        alpha:1.93119e-07  evals:  61  f(y):    59.6851  reject (lineSearch:5)
#                     (line search)        alpha:9.65595e-08  evals:  62  f(y):    59.6851  reject (lineSearch:6)
#                     (line search)        alpha:4.82798e-08  evals:  63  f(y):    59.6851  reject (lineSearch:7)
#                     (line search)        alpha:2.41399e-08  evals:  64  f(y):    59.6851  reject (lineSearch:8)
#                     (line search)        alpha:1.20699e-08  evals:  65  f(y):    59.6851  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   1  evals:  65  A(x):    59.6851  f:    3.29692  g:          0  h:    4.47094  |x-x'|:3.74106e-05 	stop:TinyXSteps (bad:2)
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):59.6851
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-ring of type rigid with rel [0, 0, 0]
# Ring successfully grasped by the gripper.
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):7913.21 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     7859.4  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    7845.23  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    7834.17  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    7824.73  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    7814.29  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    7808.36  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    7805.93  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    7805.72  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    7804.78  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    7804.93  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  12  f(y):     7804.6  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:       0.75  evals:  13  f(y):    7804.48  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:          1  evals:  14  f(y):    7804.46  ACCEPT
# --newton-- it:  13  |Delta|:        0.2  alpha:          1  evals:  15  f(y):    7804.42  ACCEPT
# --newton-- it:  14  |Delta|:        0.2  alpha:          1  evals:  16  f(y):    7804.73  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  17  f(y):    7804.21  ACCEPT
# --newton-- it:  15  |Delta|:        0.2  alpha:       0.75  evals:  18  f(y):    7804.36  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  19  f(y):    7804.21  ACCEPT
# --newton-- it:  16  |Delta|:        0.2  alpha:     0.5625  evals:  20  f(y):    7804.32  reject (lineSearch:0)
#                     (line search)        alpha:    0.28125  evals:  21  f(y):    7804.16  ACCEPT
# --newton-- it:  17  |Delta|:        0.2  alpha:   0.421875  evals:  22  f(y):     7804.3  reject (lineSearch:0)
#                     (line search)        alpha:   0.210938  evals:  23  f(y):    7804.16  ACCEPT
# --newton-- it:  18  |Delta|:        0.2  alpha:   0.316406  evals:  24  f(y):    7804.17  reject (lineSearch:0)
#                     (line search)        alpha:   0.158203  evals:  25  f(y):    7804.13  ACCEPT
# --newton-- it:  19  |Delta|:   0.131345  alpha:   0.237305  evals:  26  f(y):    7804.12  ACCEPT
# --newton-- it:  20  |Delta|:   0.136779  alpha:   0.355957  evals:  27  f(y):    7804.16  reject (lineSearch:0)
#                     (line search)        alpha:   0.177979  evals:  28  f(y):    7804.11  ACCEPT
# --newton-- it:  21  |Delta|:   0.162165  alpha:   0.266968  evals:  29  f(y):    7804.13  reject (lineSearch:0)
#                     (line search)        alpha:   0.133484  evals:  30  f(y):    7804.11  ACCEPT
# --newton-- it:  22  |Delta|:   0.103162  alpha:   0.200226  evals:  31  f(y):    7804.11  ACCEPT
# --newton-- it:  23  |Delta|:   0.150085  alpha:   0.300339  evals:  32  f(y):    7804.13  reject (lineSearch:0)
#                     (line search)        alpha:   0.150169  evals:  33  f(y):     7804.1  ACCEPT
# --newton-- it:  24  |Delta|:   0.126557  alpha:   0.225254  evals:  34  f(y):    7804.11  reject (lineSearch:0)
#                     (line search)        alpha:   0.112627  evals:  35  f(y):     7804.1  ACCEPT
# --newton-- it:  25  |Delta|:  0.0640263  alpha:   0.168941  evals:  36  f(y):    7804.09  ACCEPT
# --newton-- it:  26  |Delta|:  0.0568152  alpha:   0.253411  evals:  37  f(y):    7804.09  reject (lineSearch:0)
#                     (line search)        alpha:   0.126705  evals:  38  f(y):    7804.09  ACCEPT
# --newton-- it:  27  |Delta|:   0.052016  alpha:   0.190058  evals:  39  f(y):    7804.09  ACCEPT
# --newton-- it:  28  |Delta|:  0.0454253  alpha:   0.285087  evals:  40  f(y):    7804.09  reject (lineSearch:0)
#                     (line search)        alpha:   0.142544  evals:  41  f(y):    7804.09  ACCEPT
# --newton-- it:  29  |Delta|:  0.0411085  alpha:   0.213815  evals:  42  f(y):    7804.09  ACCEPT
# --newton-- it:  30  |Delta|:  0.0493281  alpha:   0.320723  evals:  43  f(y):    7804.09  reject (lineSearch:0)
#                     (line search)        alpha:   0.160362  evals:  44  f(y):    7804.09  ACCEPT
# --newton-- it:  31  |Delta|:  0.0480011  alpha:   0.240542  evals:  45  f(y):    7804.09  reject (lineSearch:0)
#                     (line search)        alpha:   0.120271  evals:  46  f(y):    7804.09  ACCEPT
# --newton-- it:  32  |Delta|:  0.0289563  alpha:   0.180407  evals:  47  f(y):    7804.09  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  47  A(x):    7804.09  f:    3.36909  g:          0  h:    128.814  |x-x'|:    1.89199 	stop:DeltaConverge
# ==nlp== it:   1  evals:  47  A(x):    54608.4  mu:5
# --newton-- it:  33  |Delta|:        0.2  alpha:    0.27061  evals:  48  f(y):    54607.6  ACCEPT
# --newton-- it:  34  |Delta|:        0.2  alpha:   0.405915  evals:  49  f(y):    54607.9  reject (lineSearch:0)
#                     (line search)        alpha:   0.202958  evals:  50  f(y):    54607.6  reject (lineSearch:1)
#                     (line search)        alpha:   0.101479  evals:  51  f(y):    54607.5  ACCEPT
# --newton-- it:  35  |Delta|:        0.2  alpha:   0.152218  evals:  52  f(y):    54607.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0761091  evals:  53  f(y):    54607.6  reject (lineSearch:1)
#                     (line search)        alpha:  0.0380545  evals:  54  f(y):    54607.6  reject (lineSearch:2)
#                     (line search)        alpha:  0.0190273  evals:  55  f(y):    54607.5  ACCEPT
# --newton-- it:  36  |Delta|:  0.0528072  alpha:  0.0285409  evals:  56  f(y):    54607.5  ACCEPT
# --newton-- it:  37  |Delta|:  0.0516197  alpha:  0.0428114  evals:  57  f(y):    54607.5  ACCEPT
# --newton-- it:  38  |Delta|:   0.106073  alpha:   0.064217  evals:  58  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0321085  evals:  59  f(y):    54607.5  ACCEPT
# --newton-- it:  39  |Delta|:   0.137743  alpha:  0.0481628  evals:  60  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0240814  evals:  61  f(y):    54607.5  ACCEPT
# --newton-- it:  40  |Delta|:  0.0999904  alpha:  0.0361221  evals:  62  f(y):    54607.5  ACCEPT
# --newton-- it:  41  |Delta|:   0.158989  alpha:  0.0541831  evals:  63  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0270916  evals:  64  f(y):    54607.5  ACCEPT
# --newton-- it:  42  |Delta|:   0.149731  alpha:  0.0406373  evals:  65  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0203187  evals:  66  f(y):    54607.5  ACCEPT
# --newton-- it:  43  |Delta|:   0.068175  alpha:   0.030478  evals:  67  f(y):    54607.5  ACCEPT
# --newton-- it:  44  |Delta|:  0.0807054  alpha:   0.045717  evals:  68  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0228585  evals:  69  f(y):    54607.5  ACCEPT
# --newton-- it:  45  |Delta|:  0.0514803  alpha:  0.0342878  evals:  70  f(y):    54607.5  ACCEPT
# --newton-- it:  46  |Delta|:  0.0750023  alpha:  0.0514316  evals:  71  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0257158  evals:  72  f(y):    54607.5  ACCEPT
# --newton-- it:  47  |Delta|:  0.0632174  alpha:  0.0385737  evals:  73  f(y):    54607.5  ACCEPT
# --newton-- it:  48  |Delta|:   0.111485  alpha:  0.0578606  evals:  74  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0289303  evals:  75  f(y):    54607.5  ACCEPT
# --newton-- it:  49  |Delta|:   0.119669  alpha:  0.0433954  evals:  76  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0216977  evals:  77  f(y):    54607.5  ACCEPT
# --newton-- it:  50  |Delta|:  0.0664974  alpha:  0.0325466  evals:  78  f(y):    54607.5  ACCEPT
# --newton-- it:  51  |Delta|:   0.088658  alpha:  0.0488199  evals:  79  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0244099  evals:  80  f(y):    54607.5  ACCEPT
# --newton-- it:  52  |Delta|:  0.0664797  alpha:  0.0366149  evals:  81  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0183075  evals:  82  f(y):    54607.5  ACCEPT
# --newton-- it:  53  |Delta|:   0.020724  alpha:  0.0274612  evals:  83  f(y):    54607.5  ACCEPT
# --newton-- it:  54  |Delta|:  0.0200594  alpha:  0.0411918  evals:  84  f(y):    54607.5  ACCEPT
# --newton-- it:  55  |Delta|:  0.0391714  alpha:  0.0617877  evals:  85  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0308938  evals:  86  f(y):    54607.5  ACCEPT
# --newton-- it:  56  |Delta|:  0.0475592  alpha:  0.0463407  evals:  87  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0231704  evals:  88  f(y):    54607.5  ACCEPT
# --newton-- it:  57  |Delta|:  0.0314122  alpha:  0.0347556  evals:  89  f(y):    54607.5  ACCEPT
# --newton-- it:  58  |Delta|:  0.0468254  alpha:  0.0521333  evals:  90  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0260667  evals:  91  f(y):    54607.5  ACCEPT
# --newton-- it:  59  |Delta|:  0.0406517  alpha:     0.0391  evals:  92  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:    0.01955  evals:  93  f(y):    54607.5  ACCEPT
# --newton-- it:  60  |Delta|:  0.0163195  alpha:   0.029325  evals:  94  f(y):    54607.5  ACCEPT
# --newton-- it:  61  |Delta|:   0.017984  alpha:  0.0439875  evals:  95  f(y):    54607.5  ACCEPT
# --newton-- it:  62  |Delta|:  0.0387062  alpha:  0.0659813  evals:  96  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0329906  evals:  97  f(y):    54607.5  ACCEPT
# --newton-- it:  63  |Delta|:  0.0528244  alpha:  0.0494859  evals:  98  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.024743  evals:  99  f(y):    54607.5  ACCEPT
# --newton-- it:  64  |Delta|:  0.0408636  alpha:  0.0371145  evals: 100  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0185572  evals: 101  f(y):    54607.5  ACCEPT
# --newton-- it:  65  |Delta|:   0.013901  alpha:  0.0278358  evals: 102  f(y):    54607.5  ACCEPT
# --newton-- it:  66  |Delta|:   0.013643  alpha:  0.0417538  evals: 103  f(y):    54607.5  ACCEPT
# --newton-- it:  67  |Delta|:  0.0267231  alpha:  0.0626306  evals: 104  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0313153  evals: 105  f(y):    54607.5  ACCEPT
# --newton-- it:  68  |Delta|:  0.0332538  alpha:   0.046973  evals: 106  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0234865  evals: 107  f(y):    54607.5  ACCEPT
# --newton-- it:  69  |Delta|:  0.0227197  alpha:  0.0352297  evals: 108  f(y):    54607.5  ACCEPT
# --newton-- it:  70  |Delta|:  0.0346423  alpha:  0.0528446  evals: 109  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0264223  evals: 110  f(y):    54607.5  ACCEPT
# --newton-- it:  71  |Delta|:  0.0309598  alpha:  0.0396335  evals: 111  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0198167  evals: 112  f(y):    54607.5  ACCEPT
# --newton-- it:  72  |Delta|:   0.013019  alpha:  0.0297251  evals: 113  f(y):    54607.5  ACCEPT
# --newton-- it:  73  |Delta|:  0.0147197  alpha:  0.0445876  evals: 114  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0222938  evals: 115  f(y):    54607.5  ACCEPT
# --newton-- it:  74  |Delta|:  0.0116848  alpha:  0.0334407  evals: 116  f(y):    54607.5  ACCEPT
# --newton-- it:  75  |Delta|:  0.0122954  alpha:  0.0501611  evals: 117  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0250805  evals: 118  f(y):    54607.5  ACCEPT
# --newton-- it:  76  |Delta|:  0.0112333  alpha:  0.0376208  evals: 119  f(y):    54607.5  ACCEPT
# --newton-- it:  77  |Delta|:  0.0166392  alpha:  0.0564312  evals: 120  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0282156  evals: 121  f(y):    54607.5  ACCEPT
# --newton-- it:  78  |Delta|:  0.0170107  alpha:  0.0423234  evals: 122  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0211617  evals: 123  f(y):    54607.5  ACCEPT
# --newton-- it:  79  |Delta|:   0.010594  alpha:  0.0317426  evals: 124  f(y):    54607.5  ACCEPT
# --newton-- it:  80  |Delta|:  0.0112057  alpha:  0.0476138  evals: 125  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0238069  evals: 126  f(y):    54607.5  ACCEPT
# --newton-- it:  81  |Delta|:  0.0102052  alpha:  0.0357104  evals: 127  f(y):    54607.5  ACCEPT
# --newton-- it:  82  |Delta|:  0.0123417  alpha:  0.0535656  evals: 128  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0267828  evals: 129  f(y):    54607.5  ACCEPT
# --newton-- it:  83  |Delta|:  0.0113495  alpha:  0.0401742  evals: 130  f(y):    54607.5  ACCEPT
# --newton-- it:  84  |Delta|:  0.0213281  alpha:  0.0602613  evals: 131  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0301306  evals: 132  f(y):    54607.5  ACCEPT
# --newton-- it:  85  |Delta|:  0.0247323  alpha:   0.045196  evals: 133  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.022598  evals: 134  f(y):    54607.5  ACCEPT
# --newton-- it:  86  |Delta|:  0.0153289  alpha:   0.033897  evals: 135  f(y):    54607.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0169485  evals: 136  f(y):    54607.5  ACCEPT
# --newton-- it:  87  |Delta|: 0.00908664  alpha:  0.0254227  evals: 137  f(y):    54607.5  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals: 137  A(x):    54607.5  f:    3.70869  g:          0  h:    128.837  |x-x'|:   0.071764 	stop:DeltaConverge
# ==nlp== it:   2  evals: 137  A(x):     288623  mu:25
# --newton-- it:  88  |Delta|:        0.2  alpha:  0.0381341  evals: 138  f(y):     288623  ACCEPT
# --newton-- it:  89  |Delta|:        0.2  alpha:  0.0572011  evals: 139  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha:  0.0286006  evals: 140  f(y):     288623  ACCEPT
# --newton-- it:  90  |Delta|:        0.2  alpha:  0.0429009  evals: 141  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha:  0.0214504  evals: 142  f(y):     288623  reject (lineSearch:1)
#                     (line search)        alpha:  0.0107252  evals: 143  f(y):     288623  ACCEPT
# --newton-- it:  91  |Delta|:   0.153304  alpha:  0.0160878  evals: 144  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00804391  evals: 145  f(y):     288623  reject (lineSearch:1)
#                     (line search)        alpha: 0.00402195  evals: 146  f(y):     288623  ACCEPT
# --newton-- it:  92  |Delta|:  0.0766817  alpha: 0.00603293  evals: 147  f(y):     288623  ACCEPT
# --newton-- it:  93  |Delta|:  0.0928462  alpha:  0.0090494  evals: 148  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha:  0.0045247  evals: 149  f(y):     288623  ACCEPT
# --newton-- it:  94  |Delta|:  0.0617564  alpha: 0.00678705  evals: 150  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00339352  evals: 151  f(y):     288623  ACCEPT
# --newton-- it:  95  |Delta|:  0.0154527  alpha: 0.00509029  evals: 152  f(y):     288623  ACCEPT
# --newton-- it:  96  |Delta|:  0.0135172  alpha: 0.00763543  evals: 153  f(y):     288623  ACCEPT
# --newton-- it:  97  |Delta|:  0.0244991  alpha:  0.0114531  evals: 154  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00572657  evals: 155  f(y):     288623  ACCEPT
# --newton-- it:  98  |Delta|:  0.0271785  alpha: 0.00858986  evals: 156  f(y):     288623  ACCEPT
# --newton-- it:  99  |Delta|:  0.0588114  alpha:  0.0128848  evals: 157  f(y):     288623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00644239  evals: 158  f(y):     288623  reject (lineSearch:1)
#                     (line search)        alpha:  0.0032212  evals: 159  f(y):     288623  ACCEPT
# --newton-- it: 100  |Delta|:  0.0109641  alpha:  0.0048318  evals: 160  f(y):     288623  ACCEPT
# --newton-- it: 101  |Delta|: 0.00856133  alpha: 0.00724769  evals: 161  f(y):     288623  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals: 161  A(x):     288623  f:    3.76673  g:          0  h:    128.837  |x-x'|:   0.012238 	stop:DeltaConverge
# ==nlp== it:   3  evals: 161  A(x): 1.4587e+06  mu:125
# --newton-- it: 102  |Delta|:        0.2  alpha:  0.0108715  evals: 162  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 103  |Delta|:        0.2  alpha:  0.0163073  evals: 163  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00815365  evals: 164  f(y): 1.4587e+06  reject (lineSearch:1)
#                     (line search)        alpha: 0.00407683  evals: 165  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 104  |Delta|:        0.2  alpha: 0.00611524  evals: 166  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00305762  evals: 167  f(y): 1.4587e+06  reject (lineSearch:1)
#                     (line search)        alpha: 0.00152881  evals: 168  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 105  |Delta|:        0.2  alpha: 0.00229322  evals: 169  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00114661  evals: 170  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 106  |Delta|:   0.119687  alpha: 0.00171991  evals: 171  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000859956  evals: 172  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 107  |Delta|:  0.0703811  alpha: 0.00128993  evals: 173  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 108  |Delta|:  0.0978329  alpha:  0.0019349  evals: 174  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00096745  evals: 175  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 109  |Delta|:  0.0774472  alpha: 0.00145118  evals: 176  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 110  |Delta|:   0.130657  alpha: 0.00217676  evals: 177  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00108838  evals: 178  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 111  |Delta|: Test run success? False
#   0.132658  alpha: 0.00163257  evals: 179  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000816286  evals: 180  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 112  |Delta|:  0.0678573  alpha: 0.00122443  evals: 181  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 113  |Delta|:  0.0859932  alpha: 0.00183664  evals: 182  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000918322  evals: 183  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 114  |Delta|:  0.0602337  alpha: 0.00137748  evals: 184  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 115  |Delta|:   0.093403  alpha: 0.00206622  evals: 185  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00103311  evals: 186  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 116  |Delta|:  0.0852763  alpha: 0.00154967  evals: 187  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 117  |Delta|:   0.159427  alpha:  0.0023245  evals: 188  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00116225  evals: 189  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 118  |Delta|:   0.183674  alpha: 0.00174338  evals: 190  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000871688  evals: 191  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 119  |Delta|:   0.112784  alpha: 0.00130753  evals: 192  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 120  |Delta|:   0.160274  alpha:  0.0019613  evals: 193  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000980649  evals: 194  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 121  |Delta|:   0.130754  alpha: 0.00147097  evals: 195  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000735487  evals: 196  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 122  |Delta|:  0.0473213  alpha: 0.00110323  evals: 197  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 123  |Delta|:  0.0493487  alpha: 0.00165485  evals: 198  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 124  |Delta|:   0.101865  alpha: 0.00248227  evals: 199  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00124113  evals: 200  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 125  |Delta|:    0.13224  alpha:  0.0018617  evals: 201  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000930851  evals: 202  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 126  |Delta|:  0.0956955  alpha: 0.00139628  evals: 203  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 127  |Delta|:   0.151724  alpha: 0.00209441  evals: 204  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha: 0.00104721  evals: 205  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 128  |Delta|:   0.142483  alpha: 0.00157081  evals: 206  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000785405  evals: 207  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 129  |Delta|:  0.0647271  alpha: 0.00117811  evals: 208  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 130  |Delta|:  0.0764719  alpha: 0.00176716  evals: 209  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000883581  evals: 210  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 131  |Delta|:  0.0486429  alpha: 0.00132537  evals: 211  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 132  |Delta|:  0.0707336  alpha: 0.00198806  evals: 212  f(y): 1.4587e+06  reject (lineSearch:0)
#                     (line search)        alpha:0.000994029  evals: 213  f(y): 1.4587e+06  ACCEPT
# --newton-- it: 133  |Delta|:  0.0594593  alpha: 0.00149104  evals: 214  f(y): 1.4587e+06  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   3  evals: 214  A(x): 1.4587e+06  f:    3.77753  g:          0  h:    128.837  |x-x'|: 0.00230496 	stop:TinyXSteps (bad:1)
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):1.4587e+06
# -- kin_physx.cpp:removeJoint:891(0) REMOVING JOINT 0x41bf6c0-0x42053b0 of type rigid

# %% [markdown]
# ## 2) Parameter Sweeping (Runner)
#
# We will define the ranges for:
# - **`q2_val`** in `[-0.51..-0.11]`
# - **`time1`** in `[0..0.2]`
# - **`time2`** in `[1..1.5]`
# - **`release_threshold`** in `[0.4..0.7]`
#
# Then we will loop over them, run the sim, and record the results in a CSV.

# %%
import csv

# Let's define some step sizes for each parameter
q2_vals = np.linspace(-0.51, -0.11, 5)           # e.g. 5 steps
time1_vals = np.linspace(0.0, 0.2, 3)            # e.g. 0.0, 0.1, 0.2
time2_vals = np.linspace(1.0, 1.5, 3)            # e.g. 1.0, 1.25, 1.5
release_threshes = np.linspace(0.4, 0.7, 4)      # e.g. 0.4, 0.5, 0.6, 0.7

output_file = "throw_results.csv"

with open(output_file, "w", newline="") as f:
    writer = csv.writer(f)
    # CSV header
    writer.writerow(["q2_val", "time1", "time2", "release_threshold", "success"])

    # nested loops
    for q2 in q2_vals:
        for t1 in time1_vals:
            for t2 in time2_vals:
                for rel_th in release_threshes:
                    print(f"Running with q2={q2:.2f}, t1={t1:.2f}, t2={t2:.2f}, rel_th={rel_th:.2f}")

                    success = run_ring_throw(
                        q2_val = q2,
                        time1 = t1,
                        time2 = t2,
                        release_threshold = rel_th
                    )

                    writer.writerow([q2, t1, t2, rel_th, success])

print("\nAll simulations complete. Results saved in", output_file)
# Out:
# Running with q2=-0.51, t1=0.00, t2=1.00, rel_th=0.40
# -- WARNING:kin.cpp:addFrame:193(-1) frame already exists! returning existing without modifications!
# -- WARNING:kin.cpp:addFrame:193(-1) frame already exists! returning existing without modifications!
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):110498 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     102864  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    95744.5  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    89249.4  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    83539.4  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    78800.4  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    75381.7  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    73298.5  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    72165.4  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):    71779.9  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):      71792  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  12  f(y):    71671.4  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:       0.75  evals:  13  f(y):    71576.9  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:          1  evals:  14  f(y):    71624.7  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  15  f(y):    71513.8  ACCEPT
# --newton-- it:  13  |Delta|:        0.2  alpha:       0.75  evals:  16  f(y):    71388.5  ACCEPT
# --newton-- it:  14  |Delta|:        0.2  alpha:          1  evals:  17  f(y):    71427.1  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  18  f(y):    71323.1  ACCEPT
# --newton-- it:  15  |Delta|:        0.2  alpha:       0.75  evals:  19  f(y):    71127.5  ACCEPT
# --newton-- it:  16  |Delta|:        0.2  alpha:          1  evals:  20  f(y):    71112.4  ACCEPT
# --newton-- it:  17  |Delta|:        0.2  alpha:          1  evals:  21  f(y):    70918.3  ACCEPT
# --newton-- it:  18  |Delta|:        0.2  alpha:          1  evals:  22  f(y):    70878.8  ACCEPT
# --newton-- it:  19  |Delta|:        0.2  alpha:          1  evals:  23  f(y):    70779.3  ACCEPT
# --newton-- it:  20  |Delta|:        0.2  alpha:          1  evals:  24  f(y):    70764.1  ACCEPT
# --newton-- it:  21  |Delta|:        0.2  alpha:          1  evals:  25  f(y):    70468.1  ACCEPT
# --newton-- it:  22  |Delta|:        0.2  alpha:          1  evals:  26  f(y):    70432.3  ACCEPT
# --newton-- it:  23  |Delta|:        0.2  alpha:          1  evals:  27  f(y):    70351.1  ACCEPT
# --newton-- it:  24  |Delta|:        0.2  alpha:          1  evals:  28  f(y):    70409.6  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  29  f(y):    70284.2  ACCEPT
# --newton-- it:  25  |Delta|:        0.2  alpha:       0.75  evals:  30  f(y):    70197.4  ACCEPT
# --newton-- it:  26  |Delta|:        0.2  alpha:          1  evals:  31  f(y):    70282.6  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  32  f(y):    70171.1  ACCEPT
# --newton-- it:  27  |Delta|:        0.2  alpha:       0.75  evals:  33  f(y):    70087.5  ACCEPT
# --newton-- it:  28  |Delta|:        0.2  alpha:          1  evals:  34  f(y):    69971.2  ACCEPT
# --newton-- it:  29  |Delta|:        0.2  alpha:          1  evals:  35  f(y):    69986.3  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  36  f(y):    69905.4  ACCEPT
# --newton-- it:  30  |Delta|:        0.2  alpha:       0.75  evals:  37  f(y):    69920.5  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  38  f(y):    69882.9  ACCEPT
# --newton-- it:  31  |Delta|:        0.2  alpha:     0.5625  evals:  39  f(y):    69821.2  ACCEPT
# --newton-- it:  32  |Delta|:        0.2  alpha:    0.84375  evals:  40  f(y):      69715  ACCEPT
# --newton-- it:  33  |Delta|:        0.2  alpha:          1  evals:  41  f(y):    69701.7  ACCEPT
# --newton-- it:  34  |Delta|:        0.2  alpha:          1  evals:  42  f(y):      69685  ACCEPT
# --newton-- it:  35  |Delta|:        0.2  alpha:          1  evals:  43  f(y):    69538.8  ACCEPT
# --newton-- it:  36  |Delta|:        0.2  alpha:          1  evals:  44  f(y):    69446.4  ACCEPT
# --newton-- it:  37  |Delta|:        0.2  alpha:          1  evals:  45  f(y):      69474  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  46  f(y):    69383.5  ACCEPT
# --newton-- it:  38  |Delta|:        0.2  alpha:       0.75  evals:  47  f(y):    69433.2  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  48  f(y):    69376.7  ACCEPT
# --newton-- it:  39  |Delta|:        0.2  alpha:     0.5625  evals:  49  f(y):    69345.3  ACCEPT
# --newton-- it:  40  |Delta|:        0.2  alpha:    0.84375  evals:  50  f(y):    69387.1  reject (lineSearch:0)
#                     (line search)        alpha:   0.421875  evals:  51  f(y):    69331.5  ACCEPT
# --newton-- it:  41  |Delta|:        0.2  alpha:   0.632812  evals:  52  f(y):    69340.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.316406  evals:  53  f(y):    69319.4  ACCEPT
# --newton-- it:  42  |Delta|:        0.2  alpha:   0.474609  evals:  54  f(y):    69350.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.237305  evals:  55  f(y):    69320.7  reject (lineSearch:1)
#                     (line search)        alpha:   0.118652  evals:  56  f(y):    69316.5  ACCEPT
# --newton-- it:  43  |Delta|:        0.2  alpha:   0.177979  evals:  57  f(y):      69321  reject (lineSearch:0)
#                     (line search)        alpha:  0.0889893  evals:  58  f(y):    69314.4  ACCEPT
# --newton-- it:  44  |Delta|:        0.2  alpha:   0.133484  evals:  59  f(y):    69313.4  ACCEPT
# --newton-- it:  45  |Delta|:        0.2  alpha:   0.200226  evals:  60  f(y):    69313.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.100113  evals:  61  f(y):      69309  ACCEPT
# --newton-- it:  46  |Delta|:        0.2  alpha:   0.150169  evals:  62  f(y):    69308.4  ACCEPT
# --newton-- it:  47  |Delta|:        0.2  alpha:   0.225254  evals:  63  f(y):    69302.1  ACCEPT
# --newton-- it:  48  |Delta|:        0.2  alpha:   0.337881  evals:  64  f(y):    69322.2  reject (lineSearch:0)
#                     (line search)        alpha:   0.168941  evals:  65  f(y):    69298.2  ACCEPT
# --newton-- it:  49  |Delta|:        0.2  alpha:   0.253411  evals:  66  f(y):    69307.7  reject (lineSearch:0)
#                     (line search)        alpha:   0.126705  evals:  67  f(y):    69294.5  ACCEPT
# --newton-- it:  50  |Delta|:        0.2  alpha:   0.190058  evals:  68  f(y):    69299.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0950291  evals:  69  f(y):    69292.2  ACCEPT
# --newton-- it:  51  |Delta|:        0.2  alpha:   0.142544  evals:  70  f(y):    69292.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0712718  evals:  71  f(y):    69289.9  ACCEPT
# --newton-- it:  52  |Delta|:        0.2  alpha:   0.106908  evals:  72  f(y):    69288.5  ACCEPT
# --newton-- it:  53  |Delta|:        0.2  alpha:   0.160362  evals:  73  f(y):    69286.3  ACCEPT
# --newton-- it:  54  |Delta|:        0.2  alpha:   0.240542  evals:  74  f(y):    69292.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.120271  evals:  75  f(y):    69282.3  ACCEPT
# --newton-- it:  55  |Delta|:        0.2  alpha:   0.180407  evals:  76  f(y):    69286.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0902034  evals:  77  f(y):    69280.4  ACCEPT
# --newton-- it:  56  |Delta|:        0.2  alpha:   0.135305  evals:  78  f(y):    69279.9  ACCEPT
# --newton-- it:  57  |Delta|:        0.2  alpha:   0.202958  evals:  79  f(y):    69280.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.101479  evals:  80  f(y):    69275.3  ACCEPT
# --newton-- it:  58  |Delta|:        0.2  alpha:   0.152218  evals:  81  f(y):    69275.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0761091  evals:  82  f(y):    69272.5  ACCEPT
# --newton-- it:  59  |Delta|:        0.2  alpha:   0.114164  evals:  83  f(y):    69270.1  ACCEPT
# --newton-- it:  60  |Delta|:        0.2  alpha:   0.171245  evals:  84  f(y):    69272.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0856227  evals:  85  f(y):    69267.5  ACCEPT
# --newton-- it:  61  |Delta|:        0.2  alpha:   0.128434  evals:  86  f(y):    69267.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.064217  evals:  87  f(y):    69265.6  ACCEPT
# --newton-- it:  62  |Delta|:        0.2  alpha:  0.0963256  evals:  88  f(y):    69264.1  ACCEPT
# --newton-- it:  63  |Delta|:        0.2  alpha:   0.144488  evals:  89  f(y):      69263  ACCEPT
# --newton-- it:  64  |Delta|:        0.2  alpha:   0.216733  evals:  90  f(y):    69265.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.108366  evals:  91  f(y):    69258.9  ACCEPT
# --newton-- it:  65  |Delta|:        0.2  alpha:   0.162549  evals:  92  f(y):    69261.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0812747  evals:  93  f(y):    69257.1  ACCEPT
# --newton-- it:  66  |Delta|:        0.2  alpha:   0.121912  evals:  94  f(y):    69255.7  ACCEPT
# --newton-- it:  67  |Delta|:        0.2  alpha:   0.182868  evals:  95  f(y):    69256.9  reject (lineSearch:0)
#                     (line search)        alpha:   0.091434  evals:  96  f(y):    69252.5  ACCEPT
# --newton-- it:  68  |Delta|:        0.2  alpha:   0.137151  evals:  97  f(y):    69252.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0685755  evals:  98  f(y):    69250.5  ACCEPT
# --newton-- it:  69  |Delta|:        0.2  alpha:   0.102863  evals:  99  f(y):    69248.9  ACCEPT
# --newton-- it:  70  |Delta|:        0.2  alpha:   0.154295  evals: 100  f(y):    69249.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0771475  evals: 101  f(y):    69246.3  ACCEPT
# --newton-- it:  71  |Delta|:        0.2  alpha:   0.115721  evals: 102  f(y):    69244.9  ACCEPT
# --newton-- it:  72  |Delta|:        0.2  alpha:   0.173582  evals: 103  f(y):    69241.8  ACCEPT
# --newton-- it:  73  |Delta|:        0.2  alpha:   0.260373  evals: 104  f(y):    69251.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.130186  evals: 105  f(y):    69238.7  ACCEPT
# --newton-- it:  74  |Delta|:        0.2  alpha:    0.19528  evals: 106  f(y):    69243.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0976398  evals: 107  f(y):    69236.6  ACCEPT
# --newton-- it:  75  |Delta|:        0.2  alpha:    0.14646  evals: 108  f(y):    69237.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0732298  evals: 109  f(y):    69234.6  ACCEPT
# --newton-- it:  76  |Delta|:        0.2  alpha:   0.109845  evals: 110  f(y):    69233.8  ACCEPT
# --newton-- it:  77  |Delta|:        0.2  alpha:   0.164767  evals: 111  f(y):      69232  ACCEPT
# --newton-- it:  78  |Delta|:        0.2  alpha:   0.247151  evals: 112  f(y):    69238.7  reject (lineSearch:0)
#                     (line search)        alpha:   0.123575  evals: 113  f(y):    69228.2  ACCEPT
# --newton-- it:  79  |Delta|:        0.2  alpha:   0.185363  evals: 114  f(y):    69233.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0926815  evals: 115  f(y):    69226.7  ACCEPT
# --newton-- it:  80  |Delta|:        0.2  alpha:   0.139022  evals: 116  f(y):    69226.5  ACCEPT
# --newton-- it:  81  |Delta|:        0.2  alpha:   0.208533  evals: 117  f(y):    69227.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.104267  evals: 118  f(y):      69222  ACCEPT
# --newton-- it:  82  |Delta|:        0.2  alpha:     0.1564  evals: 119  f(y):    69224.5  reject (lineSearch:0)
#                     (line search)        alpha:     0.0782  evals: 120  f(y):      69220  ACCEPT
# --newton-- it:  83  |Delta|:        0.2  alpha:     0.1173  evals: 121  f(y):    69218.1  ACCEPT
# --newton-- it:  84  |Delta|:        0.2  alpha:    0.17595  evals: 122  f(y):    69220.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.087975  evals: 123  f(y):    69215.5  ACCEPT
# --newton-- it:  85  |Delta|:        0.2  alpha:   0.131963  evals: 124  f(y):    69216.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0659813  evals: 125  f(y):    69213.9  ACCEPT
# --newton-- it:  86  |Delta|:        0.2  alpha:  0.0989719  evals: 126  f(y):    69212.8  ACCEPT
# --newton-- it:  87  |Delta|:        0.2  alpha:   0.148458  evals: 127  f(y):    69212.2  ACCEPT
# --newton-- it:  88  |Delta|:        0.2  alpha:   0.222687  evals: 128  f(y):    69215.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.111343  evals: 129  f(y):    69208.1  ACCEPT
# --newton-- it:  89  |Delta|:        0.2  alpha:   0.167015  evals: 130  f(y):    69211.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0835075  evals: 131  f(y):    69206.7  ACCEPT
# --newton-- it:  90  |Delta|:        0.2  alpha:   0.125261  evals: 132  f(y):    69205.5  ACCEPT
# --newton-- it:  91  |Delta|:        0.2  alpha:   0.187892  evals: 133  f(y):    69207.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.093946  evals: 134  f(y):    69202.5  ACCEPT
# --newton-- it:  92  |Delta|:        0.2  alpha:   0.140919  evals: 135  f(y):    69203.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0704595  evals: 136  f(y):    69200.9  ACCEPT
# --newton-- it:  93  |Delta|:        0.2  alpha:   0.105689  evals: 137  f(y):    69199.7  ACCEPT
# --newton-- it:  94  |Delta|:        0.2  alpha:   0.158534  evals: 138  f(y):    69200.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0792669  evals: 139  f(y):    69197.1  ACCEPT
# --newton-- it:  95  |Delta|:        0.2  alpha:     0.1189  evals: 140  f(y):    69196.4  ACCEPT
# --newton-- it:  96  |Delta|:        0.2  alpha:   0.178351  evals: 141  f(y):    69193.4  ACCEPT
# --newton-- it:  97  |Delta|:        0.2  alpha:   0.267526  evals: 142  f(y):    69204.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.133763  evals: 143  f(y):    69190.5  ACCEPT
# --newton-- it:  98  |Delta|:        0.2  alpha:   0.200644  evals: 144  f(y):    69196.2  reject (lineSearch:0)
#                     (line search)        alpha:   0.100322  evals: 145  f(y):    69188.5  ACCEPT
# --newton-- it:  99  |Delta|:        0.2  alpha:   0.150483  evals: 146  f(y):    69190.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0752416  evals: 147  f(y):    69186.7  ACCEPT
# --newton-- it: 100  |Delta|:        0.2  alpha:   0.112862  evals: 148  f(y):    69186.5  ACCEPT
# --newton-- it: 101  |Delta|:        0.2  alpha:   0.169294  evals: 149  f(y):    69185.2  ACCEPT
# --newton-- it: 102  |Delta|:        0.2  alpha:   0.253941  evals: 150  f(y):    69192.6  reject (lineSearch:0)
#                     (line search)        alpha:    0.12697  evals: 151  f(y):    69181.3  ACCEPT
# --newton-- it: 103  |Delta|:        0.2  alpha:   0.190455  evals: 152  f(y):    69187.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0952277  evals: 153  f(y):    69180.1  ACCEPT
# --newton-- it: 104  |Delta|:        0.2  alpha:   0.142842  evals: 154  f(y):    69180.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0714208  evals: 155  f(y):    69177.8  ACCEPT
# --newton-- it: 105  |Delta|:        0.2  alpha:   0.107131  evals: 156  f(y):    69176.5  ACCEPT
# --newton-- it: 106  |Delta|:        0.2  alpha:   0.160697  evals: 157  f(y):    69173.8  ACCEPT
# --newton-- it: 107  |Delta|:        0.2  alpha:   0.241045  evals: 158  f(y):    69182.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.120523  evals: 159  f(y):    69171.3  ACCEPT
# --newton-- it: 108  |Delta|:        0.2  alpha:   0.180784  evals: 160  f(y):    69175.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0903919  evals: 161  f(y):    69169.6  ACCEPT
# --newton-- it: 109  |Delta|:        0.2  alpha:   0.135588  evals: 162  f(y):    69170.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0677939  evals: 163  f(y):    69167.9  ACCEPT
# --newton-- it: 110  |Delta|:        0.2  alpha:   0.101691  evals: 164  f(y):    69167.3  ACCEPT
# --newton-- it: 111  |Delta|:        0.2  alpha:   0.152536  evals: 165  f(y):    69166.2  ACCEPT
# --newton-- it: 112  |Delta|:        0.2  alpha:   0.228805  evals: 166  f(y):    69171.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.114402  evals: 167  f(y):    69162.8  ACCEPT
# --newton-- it: 113  |Delta|:        0.2  alpha:   0.171603  evals: 168  f(y):    69167.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0858017  evals: 169  f(y):    69161.7  ACCEPT
# --newton-- it: 114  |Delta|:        0.2  alpha:   0.128703  evals: 170  f(y):    69161.5  ACCEPT
# --newton-- it: 115  |Delta|:        0.2  alpha:   0.193054  evals: 171  f(y):    69162.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0965269  evals: 172  f(y):    69157.9  ACCEPT
# --newton-- it: 116  |Delta|:        0.2  alpha:    0.14479  evals: 173  f(y):    69160.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0723952  evals: 174  f(y):    69156.4  ACCEPT
# --newton-- it: 117  |Delta|:        0.2  alpha:   0.108593  evals: 175  f(y):      69155  ACCEPT
# --newton-- it: 118  |Delta|:        0.2  alpha:   0.162889  evals: 176  f(y):      69157  reject (lineSearch:0)
#                     (line search)        alpha:  0.0814446  evals: 177  f(y):    69152.9  ACCEPT
# --newton-- it: 119  |Delta|:        0.2  alpha:   0.122167  evals: 178  f(y):    69153.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0610834  evals: 179  f(y):    69151.5  ACCEPT
# --newton-- it: 120  |Delta|:        0.2  alpha:  0.0916252  evals: 180  f(y):    69150.6  ACCEPT
# --newton-- it: 121  |Delta|:        0.2  alpha:   0.137438  evals: 181  f(y):    69150.3  ACCEPT
# --newton-- it: 122  |Delta|:        0.2  alpha:   0.206157  evals: 182  f(y):    69152.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.103078  evals: 183  f(y):    69146.8  ACCEPT
# --newton-- it: 123  |Delta|:        0.2  alpha:   0.154617  evals: 184  f(y):      69150  reject (lineSearch:0)
#                     (line search)        alpha:  0.0773087  evals: 185  f(y):    69145.7  ACCEPT
# --newton-- it: 124  |Delta|:        0.2  alpha:   0.115963  evals: 186  f(y):    69144.6  ACCEPT
# --newton-- it: 125  |Delta|:        0.2  alpha:   0.173945  evals: 187  f(y):    69146.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0869723  evals: 188  f(y):    69142.2  ACCEPT
# --newton-- it: 126  |Delta|:        0.2  alpha:   0.130458  evals: 189  f(y):    69143.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0652292  evals: 190  f(y):      69141  ACCEPT
# --newton-- it: 127  |Delta|:        0.2  alpha:  0.0978439  evals: 191  f(y):    69140.1  ACCEPT
# --newton-- it: 128  |Delta|:        0.2  alpha:   0.146766  evals: 192  f(y):    69140.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0733829  evals: 193  f(y):    69137.9  ACCEPT
# --newton-- it: 129  |Delta|:        0.2  alpha:   0.110074  evals: 194  f(y):    69137.1  ACCEPT
# --newton-- it: 130  |Delta|:        0.2  alpha:   0.165112  evals: 195  f(y):    69134.4  ACCEPT
# --newton-- it: 131  |Delta|:        0.2  alpha:   0.247667  evals: 196  f(y):      69144  reject (lineSearch:0)
#                     (line search)        alpha:   0.123834  evals: 197  f(y):    69132.3  ACCEPT
# --newton-- it: 132  |Delta|:        0.2  alpha:    0.18575  evals: 198  f(y):    69136.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0928752  evals: 199  f(y):    69130.6  ACCEPT
# --newton-- it: 133  |Delta|:        0.2  alpha:   0.139313  evals: 200  f(y):      69132  reject (lineSearch:0)
#                     (line search)        alpha:  0.0696564  evals: 201  f(y):    69129.1  ACCEPT
# --newton-- it: 134  |Delta|:        0.2  alpha:   0.104485  evals: 202  f(y):      69129  ACCEPT
# --newton-- it: 135  |Delta|:        0.2  alpha:   0.156727  evals: 203  f(y):    69128.1  ACCEPT
# --newton-- it: 136  |Delta|:        0.2  alpha:    0.23509  evals: 204  f(y):    69133.9  reject (lineSearch:0)
#                     (line search)        alpha:   0.117545  evals: 205  f(y):    69124.8  ACCEPT
# --newton-- it: 137  |Delta|:        0.2  alpha:   0.176318  evals: 206  f(y):    69130.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0881589  evals: 207  f(y):    69123.9  ACCEPT
# --newton-- it: 138  |Delta|:        0.2  alpha:   0.132238  evals: 208  f(y):    69123.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0661192  evals: 209  f(y):      69122  ACCEPT
# --newton-- it: 139  |Delta|:        0.2  alpha:  0.0991788  evals: 210  f(y):    69120.7  ACCEPT
# --newton-- it: 140  |Delta|:        0.2  alpha:   0.148768  evals: 211  f(y):    69118.2  ACCEPT
# --newton-- it: 141  |Delta|:        0.2  alpha:   0.223152  evals: 212  f(y):    69125.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.111576  evals: 213  f(y):    69116.4  ACCEPT
# --newton-- it: 142  |Delta|:        0.2  alpha:   0.167364  evals: 214  f(y):    69119.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0836821  evals: 215  f(y):    69114.9  ACCEPT
# --newton-- it: 143  |Delta|:        0.2  alpha:   0.125523  evals: 216  f(y):    69115.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0627616  evals: 217  f(y):    69113.6  ACCEPT
# --newton-- it: 144  |Delta|:        0.2  alpha:  0.0941423  evals: 218  f(y):    69113.1  ACCEPT
# --newton-- it: 145  |Delta|:        0.2  alpha:   0.141214  evals: 219  f(y):    69112.3  ACCEPT
# --newton-- it: 146  |Delta|:        0.2  alpha:    0.21182  evals: 220  f(y):    69116.4  reject (lineSearch:0)
#                     (line search)        alpha:    0.10591  evals: 221  f(y):    69109.5  ACCEPT
# --newton-- it: 147  |Delta|:        0.2  alpha:   0.158865  evals: 222  f(y):    69113.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0794326  evals: 223  f(y):    69108.6  ACCEPT
# --newton-- it: 148  |Delta|:        0.2  alpha:   0.119149  evals: 224  f(y):    69108.4  ACCEPT
# --newton-- it: 149  |Delta|:        0.2  alpha:   0.178723  evals: 225  f(y):    69109.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0893617  evals: 226  f(y):    69105.6  ACCEPT
# --newton-- it: 150  |Delta|:        0.2  alpha:   0.134043  evals: 227  f(y):    69107.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0670213  evals: 228  f(y):    69104.4  ACCEPT
# --newton-- it: 151  |Delta|:        0.2  alpha:   0.100532  evals: 229  f(y):    69103.4  ACCEPT
# --newton-- it: 152  |Delta|:        0.2  alpha:   0.150798  evals: 230  f(y):    69104.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0753989  evals: 231  f(y):    69101.6  ACCEPT
# --newton-- it: 153  |Delta|:        0.2  alpha:   0.113098  evals: 232  f(y):    69102.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0565492  evals: 233  f(y):    69100.5  ACCEPT
# --newton-- it: 154  |Delta|:        0.2  alpha:  0.0848238  evals: 234  f(y):    69099.7  ACCEPT
# --newton-- it: 155  |Delta|:        0.2  alpha:   0.127236  evals: 235  f(y):    69099.6  ACCEPT
# --newton-- it: 156  |Delta|:        0.2  alpha:   0.190854  evals: 236  f(y):    69101.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0954268  evals: 237  f(y):    69096.7  ACCEPT
# --newton-- it: 157  |Delta|:        0.2  alpha:    0.14314  evals: 238  f(y):    69099.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0715701  evals: 239  f(y):    69095.7  ACCEPT
# --newton-- it: 158  |Delta|:        0.2  alpha:   0.107355  evals: 240  f(y):    69094.8  ACCEPT
# --newton-- it: 159  |Delta|:        0.2  alpha:   0.161033  evals: 241  f(y):    69096.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0805163  evals: 242  f(y):    69092.9  ACCEPT
# --newton-- it: 160  |Delta|:        0.2  alpha:   0.120774  evals: 243  f(y):    69093.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0603872  evals: 244  f(y):    69091.9  ACCEPT
# --newton-- it: 161  |Delta|:        0.2  alpha:  0.0905809  evals: 245  f(y):    69091.2  ACCEPT
# --newton-- it: 162  |Delta|:        0.2  alpha:   0.135871  evals: 246  f(y):    69091.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0679356  evals: 247  f(y):    69089.4  ACCEPT
# --newton-- it: 163  |Delta|:        0.2  alpha:   0.101903  evals: 248  f(y):    69088.5  ACCEPT
# --newton-- it: 164  |Delta|:        0.2  alpha:   0.152855  evals: 249  f(y):    69086.1  ACCEPT
# --newton-- it: 165  |Delta|:        0.2  alpha:   0.229283  evals: 250  f(y):    69094.2  reject (lineSearch:0)
#                     (line search)        alpha:   0.114641  evals: 251  f(y):    69084.5  ACCEPT
# --newton-- it: 166  |Delta|:        0.2  alpha:   0.171962  evals: 252  f(y):      69088  reject (lineSearch:0)
#                     (line search)        alpha:  0.0859811  evals: 253  f(y):      69083  ACCEPT
# --newton-- it: 167  |Delta|:        0.2  alpha:   0.128972  evals: 254  f(y):    69084.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0644858  evals: 255  f(y):    69081.9  ACCEPT
# --newton-- it: 168  |Delta|:        0.2  alpha:  0.0967287  evals: 256  f(y):    69081.8  ACCEPT
# --newton-- it: 169  |Delta|:        0.2  alpha:   0.145093  evals: 257  f(y):    69081.3  ACCEPT
# --newton-- it: 170  |Delta|:        0.2  alpha:    0.21764  evals: 258  f(y):    69085.7  reject (lineSearch:0)
#                     (line search)        alpha:    0.10882  evals: 259  f(y):    69078.4  ACCEPT
# --newton-- it: 171  |Delta|:        0.2  alpha:    0.16323  evals: 260  f(y):      69083  reject (lineSearch:0)
#                     (line search)        alpha:  0.0816148  evals: 261  f(y):    69077.8  ACCEPT
# --newton-- it: 172  |Delta|:        0.2  alpha:   0.122422  evals: 262  f(y):    69077.7  ACCEPT
# --newton-- it: 173  |Delta|:        0.2  alpha:   0.183633  evals: 263  f(y):    69079.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0918167  evals: 264  f(y):      69075  ACCEPT
# --newton-- it: 174  |Delta|:        0.2  alpha:   0.137725  evals: 265  f(y):    69077.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0688625  evals: 266  f(y):    69074.2  ACCEPT
# --newton-- it: 175  |Delta|:        0.2  alpha:   0.103294  evals: 267  f(y):    69073.3  ACCEPT
# --newton-- it: 176  |Delta|:        0.2  alpha:   0.154941  evals: 268  f(y):    69075.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0774703  evals: 269  f(y):    69071.6  ACCEPT
# --newton-- it: 177  |Delta|:        0.2  alpha:   0.116205  evals: 270  f(y):    69072.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0581027  evals: 271  f(y):    69070.7  ACCEPT
# --newton-- it: 178  |Delta|:        0.2  alpha:  0.0871541  evals: 272  f(y):    69070.1  ACCEPT
# --newton-- it: 179  |Delta|:        0.2  alpha:   0.130731  evals: 273  f(y):    69070.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0653656  evals: 274  f(y):    69068.4  ACCEPT
# --newton-- it: 180  |Delta|:        0.2  alpha:  0.0980484  evals: 275  f(y):    69067.8  ACCEPT
# --newton-- it: 181  |Delta|:        0.2  alpha:   0.147073  evals: 276  f(y):    69065.6  ACCEPT
# --newton-- it: 182  |Delta|:        0.2  alpha:   0.220609  evals: 277  f(y):    69073.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.110304  evals: 278  f(y):    69064.1  ACCEPT
# --newton-- it: 183  |Delta|:        0.2  alpha:   0.165457  evals: 279  f(y):    69067.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0827283  evals: 280  f(y):    69062.7  ACCEPT
# --newton-- it: 184  |Delta|:        0.2  alpha:   0.124092  evals: 281  f(y):      69064  reject (lineSearch:0)
#                     (line search)        alpha:  0.0620462  evals: 282  f(y):    69061.7  ACCEPT
# --newton-- it: 185  |Delta|:        0.2  alpha:  0.0930694  evals: 283  f(y):    69061.6  ACCEPT
# --newton-- it: 186  |Delta|:        0.2  alpha:   0.139604  evals: 284  f(y):    69061.2  ACCEPT
# --newton-- it: 187  |Delta|:        0.2  alpha:   0.209406  evals: 285  f(y):    69065.4  reject (lineSearch:0)
#                     (line search)        alpha:   0.104703  evals: 286  f(y):    69058.5  ACCEPT
# --newton-- it: 188  |Delta|:        0.2  alpha:   0.157055  evals: 287  f(y):    69062.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0785273  evals: 288  f(y):      69058  ACCEPT
# --newton-- it: 189  |Delta|:        0.2  alpha:   0.117791  evals: 289  f(y):      69058  reject (lineSearch:0)
#                     (line search)        alpha:  0.0588955  evals: 290  f(y):    69056.5  ACCEPT
# --newton-- it: 190  |Delta|:        0.2  alpha:  0.0883432  evals: 291  f(y):    69055.4  ACCEPT
# --newton-- it: 191  |Delta|:        0.2  alpha:   0.132515  evals: 292  f(y):    69053.4  ACCEPT
# --newton-- it: 192  |Delta|:        0.2  alpha:   0.198772  evals: 293  f(y):    69059.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0993861  evals: 294  f(y):    69052.1  ACCEPT
# --newton-- it: 193  |Delta|:        0.2  alpha:   0.149079  evals: 295  f(y):    69054.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0745396  evals: 296  f(y):    69050.9  ACCEPT
# --newton-- it: 194  |Delta|:        0.2  alpha:   0.111809  evals: 297  f(y):    69051.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0559047  evals: 298  f(y):      69050  ACCEPT
# --newton-- it: 195  |Delta|:        0.2  alpha:   0.083857  evals: 299  f(y):    69049.7  ACCEPT
# --newton-- it: 196  |Delta|:        0.2  alpha:   0.125786  evals: 300  f(y):    69049.2  ACCEPT
# --newton-- it: 197  |Delta|:        0.2  alpha:   0.188678  evals: 301  f(y):    69052.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0943391  evals: 302  f(y):      69047  ACCEPT
# --newton-- it: 198  |Delta|:        0.2  alpha:   0.141509  evals: 303  f(y):    69050.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0707543  evals: 304  f(y):    69046.4  ACCEPT
# --newton-- it: 199  |Delta|:        0.2  alpha:   0.106132  evals: 305  f(y):    69046.2  ACCEPT
# --newton-- it: 200  |Delta|:        0.2  alpha:   0.159197  evals: 306  f(y):    69047.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0795986  evals: 307  f(y):    69044.2  ACCEPT
# --newton-- it: 201  |Delta|:        0.2  alpha:   0.119398  evals: 308  f(y):    69045.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.059699  evals: 309  f(y):    69043.4  ACCEPT
# --newton-- it: 202  |Delta|:        0.2  alpha:  0.0895485  evals: 310  f(y):    69042.7  ACCEPT
# --newton-- it: 203  |Delta|:        0.2  alpha:   0.134323  evals: 311  f(y):    69043.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0671614  evals: 312  f(y):    69041.3  ACCEPT
# --newton-- it: 204  |Delta|:        0.2  alpha:   0.100742  evals: 313  f(y):    69041.7  reject (lineSearch:0)
#                     (line search)        alpha:   0.050371  evals: 314  f(y):    69040.5  ACCEPT
# --newton-- it: 205  |Delta|:        0.2  alpha:  0.0755565  evals: 315  f(y):    69039.9  ACCEPT
# --newton-- it: 206  |Delta|:        0.2  alpha:   0.113335  evals: 316  f(y):    69039.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0566674  evals: 317  f(y):    69038.7  ACCEPT
# --newton-- it: 207  |Delta|:        0.2  alpha:  0.0850011  evals: 318  f(y):    69037.8  ACCEPT
# --newton-- it: 208  |Delta|:        0.2  alpha:   0.127502  evals: 319  f(y):    69036.2  ACCEPT
# --newton-- it: 209  |Delta|:        0.2  alpha:   0.191252  evals: 320  f(y):      69041  reject (lineSearch:0)
#                     (line search)        alpha:  0.0956262  evals: 321  f(y):      69035  ACCEPT
# --newton-- it: 210  |Delta|:        0.2  alpha:   0.143439  evals: 322  f(y):    69037.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0717197  evals: 323  f(y):    69034.1  ACCEPT
# --newton-- it: 211  |Delta|:        0.2  alpha:    0.10758  evals: 324  f(y):    69034.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0537898  evals: 325  f(y):    69033.2  ACCEPT
# --newton-- it: 212  |Delta|:        0.2  alpha:  0.0806846  evals: 326  f(y):    69032.9  ACCEPT
# --newton-- it: 213  |Delta|:        0.2  alpha:   0.121027  evals: 327  f(y):    69032.4  ACCEPT
# --newton-- it: 214  |Delta|:        0.2  alpha:    0.18154  evals: 328  f(y):      69035  reject (lineSearch:0)
#                     (line search)        alpha:  0.0907702  evals: 329  f(y):    69030.6  ACCEPT
# --newton-- it: 215  |Delta|:        0.2  alpha:   0.136155  evals: 330  f(y):    69032.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0680777  evals: 331  f(y):      69030  ACCEPT
# --newton-- it: 216  |Delta|:        0.2  alpha:   0.102116  evals: 332  f(y):    69029.8  ACCEPT
# --newton-- it: 217  |Delta|:        0.2  alpha:   0.153175  evals: 333  f(y):    69030.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0765874  evals: 334  f(y):      69028  ACCEPT
# --newton-- it: 218  |Delta|:        0.2  alpha:   0.114881  evals: 335  f(y):      69029  reject (lineSearch:0)
#                     (line search)        alpha:  0.0574405  evals: 336  f(y):    69027.2  ACCEPT
# --newton-- it: 219  |Delta|:        0.2  alpha:  0.0861608  evals: 337  f(y):    69026.5  ACCEPT
# --newton-- it: 220  |Delta|:        0.2  alpha:   0.129241  evals: 338  f(y):    69027.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0646206  evals: 339  f(y):    69025.4  ACCEPT
# --newton-- it: 221  |Delta|:        0.2  alpha:  0.0969309  evals: 340  f(y):    69025.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0484654  evals: 341  f(y):    69024.6  ACCEPT
# --newton-- it: 222  |Delta|:        0.2  alpha:  0.0726982  evals: 342  f(y):    69024.1  ACCEPT
# --newton-- it: 223  |Delta|:        0.2  alpha:   0.109047  evals: 343  f(y):      69024  ACCEPT
# --newton-- it: 224  |Delta|:        0.2  alpha:   0.163571  evals: 344  f(y):    69025.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0817854  evals: 345  f(y):    69022.1  ACCEPT
# --newton-- it: 225  |Delta|:        0.2  alpha:   0.122678  evals: 346  f(y):    69023.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0613391  evals: 347  f(y):    69021.5  ACCEPT
# --newton-- it: 226  |Delta|:        0.2  alpha:  0.0920086  evals: 348  f(y):    69020.9  ACCEPT
# --newton-- it: 227  |Delta|:        0.2  alpha:   0.138013  evals: 349  f(y):      69022  reject (lineSearch:0)
#                     (line search)        alpha:  0.0690065  evals: 350  f(y):    69019.7  ACCEPT
# --newton-- it: 228  |Delta|:        0.2  alpha:    0.10351  evals: 351  f(y):    69020.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0517548  evals: 352  f(y):      69019  ACCEPT
# --newton-- it: 229  |Delta|:        0.2  alpha:  0.0776323  evals: 353  f(y):    69018.5  ACCEPT
# --newton-- it: 230  |Delta|:        0.2  alpha:   0.116448  evals: 354  f(y):    69018.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0582242  evals: 355  f(y):    69017.3  ACCEPT
# --newton-- it: 231  |Delta|:        0.2  alpha:  0.0873363  evals: 356  f(y):    69016.8  ACCEPT
# --newton-- it: 232  |Delta|:        0.2  alpha:   0.131004  evals: 357  f(y):    69015.2  ACCEPT
# --newton-- it: 233  |Delta|:        0.2  alpha:   0.196507  evals: 358  f(y):    69020.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0982533  evals: 359  f(y):    69014.1  ACCEPT
# --newton-- it: 234  |Delta|:        0.2  alpha:    0.14738  evals: 360  f(y):    69016.3  reject (lineSearch:0)
#                     (line search)        alpha:    0.07369  evals: 361  f(y):    69013.2  ACCEPT
# --newton-- it: 235  |Delta|:        0.2  alpha:   0.110535  evals: 362  f(y):      69014  reject (lineSearch:0)
#                     (line search)        alpha:  0.0552675  evals: 363  f(y):    69012.5  ACCEPT
# --newton-- it: 236  |Delta|:        0.2  alpha:  0.0829012  evals: 364  f(y):    69012.4  ACCEPT
# --newton-- it: 237  |Delta|:        0.2  alpha:   0.124352  evals: 365  f(y):      69012  ACCEPT
# --newton-- it: 238  |Delta|:        0.2  alpha:   0.186528  evals: 366  f(y):    69014.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0932639  evals: 367  f(y):    69010.2  ACCEPT
# --newton-- it: 239  |Delta|:        0.2  alpha:   0.139896  evals: 368  f(y):      69013  reject (lineSearch:0)
#                     (line search)        alpha:  0.0699479  evals: 369  f(y):    69009.7  ACCEPT
# --newton-- it: 240  |Delta|:        0.2  alpha:   0.104922  evals: 370  f(y):    69009.7  ACCEPT
# --newton-- it: 241  |Delta|:        0.2  alpha:   0.157383  evals: 371  f(y):    69010.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0786914  evals: 372  f(y):    69007.9  ACCEPT
# --newton-- it: 242  |Delta|:        0.2  alpha:   0.118037  evals: 373  f(y):    69009.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0590186  evals: 374  f(y):    69007.4  ACCEPT
# --newton-- it: 243  |Delta|:        0.2  alpha:  0.0885278  evals: 375  f(y):    69006.8  ACCEPT
# --newton-- it: 244  |Delta|:        0.2  alpha:   0.132792  evals: 376  f(y):    69007.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0663959  evals: 377  f(y):    69005.7  ACCEPT
# --newton-- it: 245  |Delta|:        0.2  alpha:  0.0995938  evals: 378  f(y):    69006.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0497969  evals: 379  f(y):    69005.1  ACCEPT
# --newton-- it: 246  |Delta|:        0.2  alpha:  0.0746954  evals: 380  f(y):    69004.7  ACCEPT
# --newton-- it: 247  |Delta|:        0.2  alpha:   0.112043  evals: 381  f(y):    69004.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0560215  evals: 382  f(y):    69003.6  ACCEPT
# --newton-- it: 248  |Delta|:        0.2  alpha:  0.0840323  evals: 383  f(y):    69003.1  ACCEPT
# --newton-- it: 249  |Delta|:        0.2  alpha:   0.126048  evals: 384  f(y):    69001.7  ACCEPT
# --newton-- it: 250  |Delta|:        0.2  alpha:   0.189073  evals: 385  f(y):    69006.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0945363  evals: 386  f(y):    69000.7  ACCEPT
# --newton-- it: 251  |Delta|:        0.2  alpha:   0.141804  evals: 387  f(y):    69002.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0709022  evals: 388  f(y):    68999.8  ACCEPT
# --newton-- it: 252  |Delta|:        0.2  alpha:   0.106353  evals: 389  f(y):    69000.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0531767  evals: 390  f(y):    68999.2  ACCEPT
# --newton-- it: 253  |Delta|:        0.2  alpha:   0.079765  evals: 391  f(y):    68999.1  ACCEPT
# --newton-- it: 254  |Delta|:        0.2  alpha:   0.119648  evals: 392  f(y):    68998.8  ACCEPT
# --newton-- it: 255  |Delta|:        0.2  alpha:   0.179471  evals: 393  f(y):    69001.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0897357  evals: 394  f(y):    68997.1  ACCEPT
# --newton-- it: 256  |Delta|:        0.2  alpha:   0.134603  evals: 395  f(y):    68999.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0673017  evals: 396  f(y):    68996.7  ACCEPT
# --newton-- it: 257  |Delta|:        0.2  alpha:   0.100953  evals: 397  f(y):    68996.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0504763  evals: 398  f(y):    68995.7  ACCEPT
# --newton-- it: 258  |Delta|:        0.2  alpha:  0.0757145  evals: 399  f(y):      68995  ACCEPT
# --newton-- it: 259  |Delta|:        0.2  alpha:   0.113572  evals: 400  f(y):    68993.6  ACCEPT
# --newton-- it: 260  |Delta|:        0.2  alpha:   0.170358  evals: 401  f(y):    68997.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0851788  evals: 402  f(y):    68992.8  ACCEPT
# --newton-- it: 261  |Delta|:        0.2  alpha:   0.127768  evals: 403  f(y):    68994.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0638841  evals: 404  f(y):      68992  ACCEPT
# --newton-- it: 262  |Delta|:        0.2  alpha:  0.0958261  evals: 405  f(y):    68992.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0479131  evals: 406  f(y):    68991.4  ACCEPT
# --newton-- it: 263  |Delta|:        0.2  alpha:  0.0718696  evals: 407  f(y):    68991.2  ACCEPT
# --newton-- it: 264  |Delta|:        0.2  alpha:   0.107804  evals: 408  f(y):    68990.9  ACCEPT
# --newton-- it: 265  |Delta|:        0.2  alpha:   0.161707  evals: 409  f(y):    68992.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0808533  evals: 410  f(y):    68989.5  ACCEPT
# --newton-- it: 266  |Delta|:        0.2  alpha:    0.12128  evals: 411  f(y):    68991.4  reject (lineSearch:0)
#                     (line search)        alpha:    0.06064  evals: 412  f(y):    68989.1  ACCEPT
# --newton-- it: 267  |Delta|:        0.2  alpha:  0.0909599  evals: 413  f(y):    68988.9  ACCEPT
# --newton-- it: 268  |Delta|:        0.2  alpha:    0.13644  evals: 414  f(y):    68989.7  reject (lineSearch:0)
#                     (line search)        alpha:    0.06822  evals: 415  f(y):    68987.6  ACCEPT
# --newton-- it: 269  |Delta|:        0.2  alpha:    0.10233  evals: 416  f(y):    68988.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.051165  evals: 417  f(y):    68987.1  ACCEPT
# --newton-- it: 270  |Delta|:        0.2  alpha:  0.0767475  evals: 418  f(y):    68986.6  ACCEPT
# --newton-- it: 271  |Delta|:        0.2  alpha:   0.115121  evals: 419  f(y):    68987.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0575606  evals: 420  f(y):    68985.7  ACCEPT
# --newton-- it: 272  |Delta|:        0.2  alpha:  0.0863409  evals: 421  f(y):      68986  reject (lineSearch:0)
#                     (line search)        alpha:  0.0431704  evals: 422  f(y):    68985.2  ACCEPT
# --newton-- it: 273  |Delta|:        0.2  alpha:  0.0647557  evals: 423  f(y):    68984.8  ACCEPT
# --newton-- it: 274  |Delta|:        0.2  alpha:  0.0971335  evals: 424  f(y):    68984.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0485667  evals: 425  f(y):      68984  ACCEPT
# --newton-- it: 275  |Delta|:        0.2  alpha:  0.0728501  evals: 426  f(y):    68983.5  ACCEPT
# --newton-- it: 276  |Delta|:        0.2  alpha:   0.109275  evals: 427  f(y):    68982.4  ACCEPT
# --newton-- it: 277  |Delta|:        0.2  alpha:   0.163913  evals: 428  f(y):    68985.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0819564  evals: 429  f(y):    68981.6  ACCEPT
# --newton-- it: 278  |Delta|:        0.2  alpha:   0.122935  evals: 430  f(y):    68982.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0614673  evals: 431  f(y):      68981  ACCEPT
# --newton-- it: 279  |Delta|:        0.2  alpha:  0.0922009  evals: 432  f(y):    68981.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0461005  evals: 433  f(y):    68980.4  ACCEPT
# --newton-- it: 280  |Delta|:        0.2  alpha:  0.0691507  evals: 434  f(y):    68980.2  ACCEPT
# --newton-- it: 281  |Delta|:        0.2  alpha:   0.103726  evals: 435  f(y):    68979.8  ACCEPT
# --newton-- it: 282  |Delta|:        0.2  alpha:   0.155589  evals: 436  f(y):    68981.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0777945  evals: 437  f(y):    68978.6  ACCEPT
# --newton-- it: 283  |Delta|:        0.2  alpha:   0.116692  evals: 438  f(y):    68980.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0583459  evals: 439  f(y):    68978.3  ACCEPT
# --newton-- it: 284  |Delta|:        0.2  alpha:  0.0875189  evals: 440  f(y):    68978.1  ACCEPT
# --newton-- it: 285  |Delta|:        0.2  alpha:   0.131278  evals: 441  f(y):    68978.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0656391  evals: 442  f(y):    68976.9  ACCEPT
# --newton-- it: 286  |Delta|:        0.2  alpha:  0.0984587  evals: 443  f(y):    68977.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0492294  evals: 444  f(y):    68976.4  ACCEPT
# --newton-- it: 287  |Delta|:        0.2  alpha:   0.073844  evals: 445  f(y):    68975.9  ACCEPT
# --newton-- it: 288  |Delta|:        0.2  alpha:   0.110766  evals: 446  f(y):    68976.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.055383  evals: 447  f(y):    68975.2  ACCEPT
# --newton-- it: 289  |Delta|:        0.2  alpha:  0.0830745  evals: 448  f(y):    68975.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0415373  evals: 449  f(y):    68974.7  ACCEPT
# --newton-- it: 290  |Delta|:        0.2  alpha:  0.0623059  evals: 450  f(y):    68974.4  ACCEPT
# --newton-- it: 291  |Delta|:        0.2  alpha:  0.0934589  evals: 451  f(y):    68974.3  ACCEPT
# --newton-- it: 292  |Delta|:        0.2  alpha:   0.140188  evals: 452  f(y):    68975.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0700941  evals: 453  f(y):    68973.1  ACCEPT
# --newton-- it: 293  |Delta|:        0.2  alpha:   0.105141  evals: 454  f(y):    68974.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0525706  evals: 455  f(y):    68972.6  ACCEPT
# --newton-- it: 294  |Delta|:        0.2  alpha:  0.0788559  evals: 456  f(y):    68972.2  ACCEPT
# --newton-- it: 295  |Delta|:        0.2  alpha:   0.118284  evals: 457  f(y):    68972.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0591419  evals: 458  f(y):    68971.4  ACCEPT
# --newton-- it: 296  |Delta|:        0.2  alpha:  0.0887129  evals: 459  f(y):    68971.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0443564  evals: 460  f(y):      68971  ACCEPT
# --newton-- it: 297  |Delta|:        0.2  alpha:  0.0665347  evals: 461  f(y):    68970.7  ACCEPT
# --newton-- it: 298  |Delta|:        0.2  alpha:   0.099802  evals: 462  f(y):    68970.8  reject (lineSearch:0)
#                     (line search)        alpha:   0.049901  evals: 463  f(y):    68969.9  ACCEPT
# --newton-- it: 299  |Delta|:        0.2  alpha:  0.0748515  evals: 464  f(y):    68969.5  ACCEPT
# --newton-- it: 300  |Delta|:        0.2  alpha:   0.112277  evals: 465  f(y):    68968.5  ACCEPT
# --newton-- it: 301  |Delta|:        0.2  alpha:   0.168416  evals: 466  f(y):    68971.7  reject (lineSearch:0)
# ...
#                     (line search)        alpha:   0.045575  evals: 498  f(y):    68957.9  ACCEPT
# --newton-- it: 321  |Delta|:        0.2  alpha:  0.0683626  evals: 499  f(y):    68957.8  ACCEPT
# --newton-- it: 322  |Delta|:        0.2  alpha:   0.102544  evals: 500  f(y):    68957.6  ACCEPT
# --newton-- it: 323  |Delta|:        0.2  alpha:   0.153816  evals: 501  f(y):    68959.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0769079  evals: 502  f(y):    68956.5  ACCEPT
# --newton-- it: 324  |Delta|:        0.2  alpha:   0.115362  evals: 503  f(y):    68958.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0576809  evals: 504  f(y):    68956.3  ACCEPT
# --newton-- it: 325  |Delta|:        0.2  alpha:  0.0865214  evals: 505  f(y):    68956.2  ACCEPT
# --newton-- it: 326  |Delta|:        0.2  alpha:   0.129782  evals: 506  f(y):    68956.9  reject (lineSearch:0)
#                     (line search)        alpha:   0.064891  evals: 507  f(y):    68955.2  ACCEPT
# --newton-- it: 327  |Delta|:        0.2  alpha:  0.0973365  evals: 508  f(y):      68956  reject (lineSearch:0)
#                     (line search)        alpha:  0.0486683  evals: 509  f(y):    68954.8  ACCEPT
# --newton-- it: 328  |Delta|:        0.2  alpha:  0.0730024  evals: 510  f(y):    68954.5  ACCEPT
# --newton-- it: 329  |Delta|:        0.2  alpha:   0.109504  evals: 511  f(y):    68955.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0547518  evals: 512  f(y):    68953.8  ACCEPT
# --newton-- it: 330  |Delta|:        0.2  alpha:  0.0821277  evals: 513  f(y):    68954.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0410639  evals: 514  f(y):    68953.5  ACCEPT
# --newton-- it: 331  |Delta|:        0.2  alpha:  0.0615958  evals: 515  f(y):    68953.2  ACCEPT
# --newton-- it: 332  |Delta|:        0.2  alpha:  0.0923937  evals: 516  f(y):    68953.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0461968  evals: 517  f(y):    68952.6  ACCEPT
# --newton-- it: 333  |Delta|:        0.2  alpha:  0.0692952  evals: 518  f(y):    68952.3  ACCEPT
# --newton-- it: 334  |Delta|:        0.2  alpha:   0.103943  evals: 519  f(y):    68951.4  ACCEPT
# --newton-- it: 335  |Delta|:        0.2  alpha:   0.155914  evals: 520  f(y):    68954.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0779572  evals: 521  f(y):    68950.9  ACCEPT
# --newton-- it: 336  |Delta|:        0.2  alpha:   0.116936  evals: 522  f(y):      68952  reject (lineSearch:0)
#                     (line search)        alpha:  0.0584679  evals: 523  f(y):    68950.4  ACCEPT
# --newton-- it: 337  |Delta|:        0.2  alpha:  0.0877018  evals: 524  f(y):    68950.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0438509  evals: 525  f(y):      68950  ACCEPT
# --newton-- it: 338  |Delta|:        0.2  alpha:  0.0657763  evals: 526  f(y):    68949.9  ACCEPT
# --newton-- it: 339  |Delta|:        0.2  alpha:  0.0986645  evals: 527  f(y):    68949.7  ACCEPT
# --newton-- it: 340  |Delta|:        0.2  alpha:   0.147997  evals: 528  f(y):    68951.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0739984  evals: 529  f(y):    68948.7  ACCEPT
# --newton-- it: 341  |Delta|:        0.2  alpha:   0.110998  evals: 530  f(y):    68950.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0554988  evals: 531  f(y):    68948.5  ACCEPT
# --newton-- it: 342  |Delta|:        0.2  alpha:  0.0832482  evals: 532  f(y):    68948.5  ACCEPT
# --newton-- it: 343  |Delta|:        0.2  alpha:   0.124872  evals: 533  f(y):      68949  reject (lineSearch:0)
#                     (line search)        alpha:  0.0624361  evals: 534  f(y):    68947.5  ACCEPT
# --newton-- it: 344  |Delta|:        0.2  alpha:  0.0936542  evals: 535  f(y):    68948.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0468271  evals: 536  f(y):    68947.2  ACCEPT
# --newton-- it: 345  |Delta|:        0.2  alpha:  0.0702407  evals: 537  f(y):    68946.9  ACCEPT
# --newton-- it: 346  |Delta|:        0.2  alpha:   0.105361  evals: 538  f(y):    68947.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0526805  evals: 539  f(y):    68946.3  ACCEPT
# --newton-- it: 347  |Delta|:        0.2  alpha:  0.0790207  evals: 540  f(y):    68946.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0395104  evals: 541  f(y):      68946  ACCEPT
# --newton-- it: 348  |Delta|:        0.2  alpha:  0.0592656  evals: 542  f(y):    68945.8  ACCEPT
# --newton-- it: 349  |Delta|:        0.2  alpha:  0.0888983  evals: 543  f(y):    68945.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0444492  evals: 544  f(y):    68945.2  ACCEPT
# --newton-- it: 350  |Delta|:        0.2  alpha:  0.0666738  evals: 545  f(y):    68944.9  ACCEPT
# --newton-- it: 351  |Delta|:        0.2  alpha:   0.100011  evals: 546  f(y):    68944.1  ACCEPT
# --newton-- it: 352  |Delta|:        0.2  alpha:   0.150016  evals: 547  f(y):    68946.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.075008  evals: 548  f(y):    68943.6  ACCEPT
# --newton-- it: 353  |Delta|:        0.2  alpha:   0.112512  evals: 549  f(y):    68944.7  reject (lineSearch:0)
#                     (line search)        alpha:   0.056256  evals: 550  f(y):    68943.2  ACCEPT
# --newton-- it: 354  |Delta|:        0.2  alpha:   0.084384  evals: 551  f(y):    68943.6  reject (lineSearch:0)
#                     (line search)        alpha:   0.042192  evals: 552  f(y):    68942.8  ACCEPT
# --newton-- it: 355  |Delta|:        0.2  alpha:   0.063288  evals: 553  f(y):    68942.8  ACCEPT
# --newton-- it: 356  |Delta|:        0.2  alpha:   0.094932  evals: 554  f(y):    68942.6  ACCEPT
# --newton-- it: 357  |Delta|:        0.2  alpha:   0.142398  evals: 555  f(y):    68943.9  reject (lineSearch:0)
#                     (line search)        alpha:   0.071199  evals: 556  f(y):    68941.7  ACCEPT
# --newton-- it: 358  |Delta|:        0.2  alpha:   0.106798  evals: 557  f(y):      68943  reject (lineSearch:0)
#                     (line search)        alpha:  0.0533992  evals: 558  f(y):    68941.5  ACCEPT
# --newton-- it: 359  |Delta|:        0.2  alpha:  0.0800988  evals: 559  f(y):    68941.4  ACCEPT
# --newton-- it: 360  |Delta|:        0.2  alpha:   0.120148  evals: 560  f(y):      68942  reject (lineSearch:0)
#                     (line search)        alpha:  0.0600741  evals: 561  f(y):    68940.6  ACCEPT
# --newton-- it: 361  |Delta|:        0.2  alpha:  0.0901112  evals: 562  f(y):    68941.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0450556  evals: 563  f(y):    68940.3  ACCEPT
# --newton-- it: 362  |Delta|:        0.2  alpha:  0.0675834  evals: 564  f(y):    68940.1  ACCEPT
# --newton-- it: 363  |Delta|:        0.2  alpha:   0.101375  evals: 565  f(y):    68940.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0506875  evals: 566  f(y):    68939.5  ACCEPT
# --newton-- it: 364  |Delta|:        0.2  alpha:  0.0760313  evals: 567  f(y):    68939.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0380157  evals: 568  f(y):    68939.2  ACCEPT
# --newton-- it: 365  |Delta|:        0.2  alpha:  0.0570235  evals: 569  f(y):      68939  ACCEPT
# --newton-- it: 366  |Delta|:        0.2  alpha:  0.0855352  evals: 570  f(y):    68939.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0427676  evals: 571  f(y):    68938.5  ACCEPT
# --newton-- it: 367  |Delta|:        0.2  alpha:  0.0641514  evals: 572  f(y):    68938.3  ACCEPT
# --newton-- it: 368  |Delta|:        0.2  alpha:  0.0962271  evals: 573  f(y):    68937.6  ACCEPT
# --newton-- it: 369  |Delta|:        0.2  alpha:   0.144341  evals: 574  f(y):    68939.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0721704  evals: 575  f(y):    68937.1  ACCEPT
# --newton-- it: 370  |Delta|:        0.2  alpha:   0.108256  evals: 576  f(y):    68938.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0541278  evals: 577  f(y):    68936.7  ACCEPT
# --newton-- it: 371  |Delta|:        0.2  alpha:  0.0811917  evals: 578  f(y):      68937  reject (lineSearch:0)
#                     (line search)        alpha:  0.0405958  evals: 579  f(y):    68936.4  ACCEPT
# --newton-- it: 372  |Delta|:        0.2  alpha:  0.0608937  evals: 580  f(y):    68936.3  ACCEPT
# --newton-- it: 373  |Delta|:        0.2  alpha:  0.0913406  evals: 581  f(y):    68936.2  ACCEPT
# --newton-- it: 374  |Delta|:        0.2  alpha:   0.137011  evals: 582  f(y):    68937.4  reject (lineSearch:0)
#                     (line search)        alpha:  0.0685055  evals: 583  f(y):    68935.4  ACCEPT
# --newton-- it: 375  |Delta|:        0.2  alpha:   0.102758  evals: 584  f(y):    68936.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0513791  evals: 585  f(y):    68935.2  ACCEPT
# --newton-- it: 376  |Delta|:        0.2  alpha:  0.0770686  evals: 586  f(y):    68935.1  ACCEPT
# --newton-- it: 377  |Delta|:        0.2  alpha:   0.115603  evals: 587  f(y):    68935.6  reject (lineSearch:0)
#                     (line search)        alpha:  0.0578015  evals: 588  f(y):    68934.4  ACCEPT
# --newton-- it: 378  |Delta|:        0.2  alpha:  0.0867022  evals: 589  f(y):      68935  reject (lineSearch:0)
#                     (line search)        alpha:  0.0433511  evals: 590  f(y):    68934.1  ACCEPT
# --newton-- it: 379  |Delta|:        0.2  alpha:  0.0650267  evals: 591  f(y):    68933.9  ACCEPT
# --newton-- it: 380  |Delta|:        0.2  alpha:    0.09754  evals: 592  f(y):    68934.3  reject (lineSearch:0)
#                     (line search)        alpha:    0.04877  evals: 593  f(y):    68933.4  ACCEPT
# --newton-- it: 381  |Delta|:        0.2  alpha:   0.073155  evals: 594  f(y):    68933.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0365775  evals: 595  f(y):    68933.1  ACCEPT
# --newton-- it: 382  |Delta|:        0.2  alpha:  0.0548662  evals: 596  f(y):      68933  ACCEPT
# --newton-- it: 383  |Delta|:        0.2  alpha:  0.0822994  evals: 597  f(y):      68933  reject (lineSearch:0)
#                     (line search)        alpha:  0.0411497  evals: 598  f(y):    68932.5  ACCEPT
# --newton-- it: 384  |Delta|:        0.2  alpha:  0.0617245  evals: 599  f(y):    68932.3  ACCEPT
# --newton-- it: 385  |Delta|:        0.2  alpha:  0.0925868  evals: 600  f(y):    68931.6  ACCEPT
# --newton-- it: 386  |Delta|:        0.2  alpha:    0.13888  evals: 601  f(y):    68933.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0694401  evals: 602  f(y):    68931.2  ACCEPT
# --newton-- it: 387  |Delta|:        0.2  alpha:    0.10416  evals: 603  f(y):    68932.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0520801  evals: 604  f(y):    68930.8  ACCEPT
# --newton-- it: 388  |Delta|:        0.2  alpha:  0.0781201  evals: 605  f(y):    68931.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0390601  evals: 606  f(y):    68930.5  ACCEPT
# --newton-- it: 389  |Delta|:        0.2  alpha:  0.0585901  evals: 607  f(y):    68930.5  ACCEPT
# --newton-- it: 390  |Delta|:        0.2  alpha:  0.0878851  evals: 608  f(y):    68930.4  ACCEPT
# --newton-- it: 391  |Delta|:        0.2  alpha:   0.131828  evals: 609  f(y):    68931.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0659138  evals: 610  f(y):    68929.6  ACCEPT
# --newton-- it: 392  |Delta|:        0.2  alpha:  0.0988708  evals: 611  f(y):    68930.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0494354  evals: 612  f(y):    68929.4  ACCEPT
# --newton-- it: 393  |Delta|:        0.2  alpha:  0.0741531  evals: 613  f(y):    68929.4  ACCEPT
# --newton-- it: 394  |Delta|:        0.2  alpha:    0.11123  evals: 614  f(y):    68929.9  reject (lineSearch:0)
#                     (line search)        alpha:  0.0556148  evals: 615  f(y):    68928.7  ACCEPT
# --newton-- it: 395  |Delta|:        0.2  alpha:  0.0834222  evals: 616  f(y):    68929.3  reject (lineSearch:0)
#                     (line search)        alpha:  0.0417111  evals: 617  f(y):    68928.5  ACCEPT
# --newton-- it: 396  |Delta|:        0.2  alpha:  0.0625667  evals: 618  f(y):    68928.3  ACCEPT
# --newton-- it: 397  |Delta|:        0.2  alpha:    0.09385  evals: 619  f(y):    68928.7  reject (lineSearch:0)
#                     (line search)        alpha:   0.046925  evals: 620  f(y):    68927.8  ACCEPT
# --newton-- it: 398  |Delta|:        0.2  alpha:  0.0703875  evals: 621  f(y):    68928.1  reject (lineSearch:0)
#                     (line search)        alpha:  0.0351937  evals: 622  f(y):    68927.6  ACCEPT
# --newton-- it: 399  |Delta|:        0.2  alpha:  0.0527906  evals: 623  f(y):    68927.4  ACCEPT
# --newton-- it: 400  |Delta|:        0.2  alpha:  0.0791859  evals: 624  f(y):    68927.5  reject (lineSearch:0)
#                     (line search)        alpha:   0.039593  evals: 625  f(y):      68927  ACCEPT
# --newton-- it: 401  |Delta|:        0.2  alpha:  0.0593894  evals: 626  f(y):    68926.9  ACCEPT
# --newton-- it: 402  |Delta|:        0.2  alpha:  0.0890842  evals: 627  f(y):    68926.3  ACCEPT
# --newton-- it: 403  |Delta|:        0.2  alpha:   0.133626  evals: 628  f(y):    68928.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0668131  evals: 629  f(y):    68925.9  ACCEPT
# --newton-- it: 404  |Delta|:        0.2  alpha:    0.10022  evals: 630  f(y):    68926.7  reject (lineSearch:0)
#                     (line search)        alpha:  0.0501098  evals: 631  f(y):    68925.5  ACCEPT
# --newton-- it: 405  |Delta|:        0.2  alpha:  0.0751648  evals: 632  f(y):    68925.8  reject (lineSearch:0)
#                     (line search)        alpha:  0.0375824  evals: 633  f(y):    68925.3  ACCEPT
# --newton-- it: 406  |Delta|:        0.2  alpha:  0.0563736  evals: 634  f(y):    68925.2  ACCEPT
# --newton-- it: 407  |Delta|:        0.2  alpha:  0.0845604  evals: 635  f(y):    68925.1  ACCEPT
# --newton-- it: 408  |Delta|:        0.2  alpha:   0.126841  evals: 636  f(y):    68926.2  reject (lineSearch:0)
#                     (line search)        alpha:  0.0634203  evals: 637  f(y):    68924.4  ACCEPT
# --newton-- it: 409  |Delta|:        0.2  alpha:  0.0951304  evals: 638  f(y):    68925.5  reject (lineSearch:0)
#                     (line search)        alpha:  0.0475652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      20                 for rel_th in release_threshes:
#      21                     print(f"Running with q2={q2:.2f}, t1={t1:.2f}, t2={t2:.2f}, rel_th={rel_th:.2f}")
# ---> 23                     success = run_ring_throw(
#      24                         q2_val = q2,
#      25                         time1 = t1,
#      26                         time2 = t2,
#      27                         release_threshold = rel_th
#      28                     )
#      30                     writer.writerow([q2, t1, t2, rel_th, success])
#      32 print("\nAll simulations complete. Results saved in", output_file)
#
# Cell In[1], line 114, in run_ring_throw(q2_val, time1, time2, release_threshold)
#     104 """
#     105 Executes the ring pick-and-throw sequence, using:
#     106   - q2_val in [-0.51..-0.11] for q[2]
#    (...)
#     110 Returns True if 'ring on pole' success, else False.
#     111 """
#     113 # 1) Align with the ring
# --> 114 grasp_path = align_gripper_to_ring()
#     115 # keep the align times as [1., 1.5]
#     116 bot.move(grasp_path, [1.0, 1.5])
#
# Cell In[1], line 40, in align_gripper_to_ring()
#      38 solver.setProblem(komo.nlp())
#      39 solver.setOptions(stopTolerance=1e-2, verbose=4)
# ---> 40 solver.solve()
#      42 return komo.getPath()
#
# KeyboardInterrupt:
